# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import SpectralClustering

# %%
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=3, min_samples=2)
dbscan.fit(X)
# Out:
# C:\Users\Ruban J\Anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\Ruban J\Anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# DBSCAN(algorithm='auto', eps=3, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=2, n_jobs=None, p=None)

# %%
print(dbscan.labels_)
# Out:
# [ 0 -1  1  2  0  2  1 -1 -1 -1  3 -1  3  4  3  4  5 -1 -1 -1  5  6 -1  6
#  -1 -1  7 -1  7 -1  8 -1  8 -1 -1 -1 -1 -1  9 -1 10 -1 10 -1  9 -1 -1 -1
#  11 11 12 13 12 13 12 -1 12 12 12 12 14 14 12 15 12 15 12 12 15 12 14 -1
#  12 14 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16
#  16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16
#  16 16 16 -1 -1 17 18 -1 19 17 19 17 18 17 19 -1 19 17 -1 17 19 -1 -1 20
#  -1 -1 21 22 23 20 23 20 23 22 23 20 24 22 24 22 21 -1 -1 -1 25 26 -1 -1
#  25 -1 27 26 27 -1 27 -1 27 -1 -1 -1 -1 28 -1 28 -1 -1 29 30 -1 -1 29 30
#  -1 -1 -1 -1 -1 -1 -1 -1]

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1])
plt.show()
