# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sklearn.cluster import Birch
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values

# %%
birch = Birch(n_clusters=3)
birch.fit(X)
# Out:
# C:\Users\Ruban J\Anaconda3\envs\aiml\lib\site-packages\sklearn\utils\validation.py:179: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < '0.12':
# Birch(branching_factor=50, compute_labels=True, copy=True, n_clusters=3,
#       threshold=0.5)

# %%
labels = birch.labels_
cluster_centers = birch.subcluster_centers_

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='*', s=150, color='r')
plt.show()
